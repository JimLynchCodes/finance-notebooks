# %% [markdown]
# # Simple Yahoo Fin Options Call
#
# More or less copied from this youtube video: https://www.youtube.com/watch?v=Lj8QHPg2Rwg
#
# Hit the play button to run!

# %%
# !pip install yahoo_fin
# Out:
# Collecting yahoo_fin
#   Obtaining dependency information for yahoo_fin from https://files.pythonhosted.org/packages/c1/73/b8d385bbc01bacb66f589a36f6c108e0e847d1f982755bfcc7391735d560/yahoo_fin-0.8.9.1-py3-none-any.whl.metadata
#   Downloading yahoo_fin-0.8.9.1-py3-none-any.whl.metadata (699 bytes)
# Collecting requests-html (from yahoo_fin)
#   Obtaining dependency information for requests-html from https://files.pythonhosted.org/packages/24/bc/a4380f09bab3a776182578ce6b2771e57259d0d4dbce178205779abdc347/requests_html-0.10.0-py3-none-any.whl.metadata
#   Downloading requests_html-0.10.0-py3-none-any.whl.metadata (15 kB)
# Collecting feedparser (from yahoo_fin)
#   Obtaining dependency information for feedparser from https://files.pythonhosted.org/packages/7c/d4/8c31aad9cc18f451c49f7f9cfb5799dadffc88177f7917bc90a66459b1d7/feedparser-6.0.11-py3-none-any.whl.metadata
#   Downloading feedparser-6.0.11-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/site-packages (from yahoo_fin) (2.31.0)
# Collecting pandas (from yahoo_fin)
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/f1/8b/617792ad1feef330e87d7459584a1f91aa8aea373d8b168ac5d24fddd808/pandas-2.2.1-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading pandas-2.2.1-cp311-cp311-macosx_10_9_x86_64.whl.metadata (19 kB)
# Collecting sgmllib3k (from feedparser->yahoo_fin)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting numpy<2,>=1.23.2 (from pandas->yahoo_fin)
#   Obtaining dependency information for numpy<2,>=1.23.2 from https://files.pythonhosted.org/packages/11/57/baae43d14fe163fa0e4c47f307b6b2511ab8d7d30177c491960504252053/numpy-1.26.4-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading numpy-1.26.4-cp311-cp311-macosx_10_9_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/site-packages (from pandas->yahoo_fin) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/site-packages (from pandas->yahoo_fin) (2023.3.post1)
# Collecting tzdata>=2022.7 (from pandas->yahoo_fin)
#   Obtaining dependency information for tzdata>=2022.7 from https://files.pythonhosted.org/packages/65/58/f9c9e6be752e9fcb8b6a0ee9fb87e6e7a1f6bcab2cdc73f02bb7ba91ada0/tzdata-2024.1-py2.py3-none-any.whl.metadata
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/site-packages (from requests->yahoo_fin) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests->yahoo_fin) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/site-packages (from requests->yahoo_fin) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests->yahoo_fin) (2023.7.22)
# Collecting pyquery (from requests-html->yahoo_fin)
#   Obtaining dependency information for pyquery from https://files.pythonhosted.org/packages/36/b7/f7ccf9e52e2817e1265d3719c600fa4ef33c07de4d5ef0ced3f43ab1cef2/pyquery-2.0.0-py3-none-any.whl.metadata
#   Downloading pyquery-2.0.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting fake-useragent (from requests-html->yahoo_fin)
#   Obtaining dependency information for fake-useragent from https://files.pythonhosted.org/packages/33/c9/ff44922639b8827dbc86d463d870dabfc19d1567d8a6427dcb2289d83fd8/fake_useragent-1.4.0-py3-none-any.whl.metadata
#   Downloading fake_useragent-1.4.0-py3-none-any.whl.metadata (13 kB)
# Collecting parse (from requests-html->yahoo_fin)
#   Obtaining dependency information for parse from https://files.pythonhosted.org/packages/ce/f0/30fe1494f1910ad3ea40639b13ac48cdb16a8600e8861cbfc2c560661ddf/parse-1.20.1-py2.py3-none-any.whl.metadata
#   Downloading parse-1.20.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting bs4 (from requests-html->yahoo_fin)
#   Obtaining dependency information for bs4 from https://files.pythonhosted.org/packages/51/bb/bf7aab772a159614954d84aa832c129624ba6c32faa559dfb200a534e50b/bs4-0.0.2-py2.py3-none-any.whl.metadata
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Collecting w3lib (from requests-html->yahoo_fin)
#   Obtaining dependency information for w3lib from https://files.pythonhosted.org/packages/82/e2/dcf8573d7153194eb673347cea1f9bbdb2a8e61030740fb6f50e4234a00b/w3lib-2.1.2-py3-none-any.whl.metadata
#   Downloading w3lib-2.1.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting pyppeteer>=0.0.14 (from requests-html->yahoo_fin)
#   Obtaining dependency information for pyppeteer>=0.0.14 from https://files.pythonhosted.org/packages/3d/ee/fb2757a38025421fd3844a0ed0a230b78c9c04a66355024436cf3005a70c/pyppeteer-2.0.0-py3-none-any.whl.metadata
#   Downloading pyppeteer-2.0.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting appdirs<2.0.0,>=1.4.3 (from pyppeteer>=0.0.14->requests-html->yahoo_fin)
#   Obtaining dependency information for appdirs<2.0.0,>=1.4.3 from https://files.pythonhosted.org/packages/3b/00/2344469e2084fb287c2e0b57b72910309874c3245463acd6cf5e3db69324/appdirs-1.4.4-py2.py3-none-any.whl.metadata
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting importlib-metadata>=1.4 (from pyppeteer>=0.0.14->requests-html->yahoo_fin)
#   Obtaining dependency information for importlib-metadata>=1.4 from https://files.pythonhosted.org/packages/c0/8b/d8427f023c081a8303e6ac7209c16e6878f2765d5b59667f3903fbcfd365/importlib_metadata-7.0.1-py3-none-any.whl.metadata
#   Downloading importlib_metadata-7.0.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting pyee<12.0.0,>=11.0.0 (from pyppeteer>=0.0.14->requests-html->yahoo_fin)
#   Obtaining dependency information for pyee<12.0.0,>=11.0.0 from https://files.pythonhosted.org/packages/16/cc/5cea8a0a0d3deb90b5a0d39ad1a6a1ccaa40a9ea86d793eb8a49d32a6ed0/pyee-11.1.0-py3-none-any.whl.metadata
#   Downloading pyee-11.1.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting tqdm<5.0.0,>=4.42.1 (from pyppeteer>=0.0.14->requests-html->yahoo_fin)
#   Obtaining dependency information for tqdm<5.0.0,>=4.42.1 from https://files.pythonhosted.org/packages/2a/14/e75e52d521442e2fcc9f1df3c5e456aead034203d4797867980de558ab34/tqdm-4.66.2-py3-none-any.whl.metadata
#   Downloading tqdm-4.66.2-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.0 MB/s eta 0:00:00
# Collecting urllib3<3,>=1.21.1 (from requests->yahoo_fin)
#   Obtaining dependency information for urllib3<3,>=1.21.1 from https://files.pythonhosted.org/packages/b0/53/aa91e163dcfd1e5b82d8a890ecf13314e3e149c05270cc644581f77f17fd/urllib3-1.26.18-py2.py3-none-any.whl.metadata
#   Downloading urllib3-1.26.18-py2.py3-none-any.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 1.7 MB/s eta 0:00:00
# Collecting websockets<11.0,>=10.0 (from pyppeteer>=0.0.14->requests-html->yahoo_fin)
#   Obtaining dependency information for websockets<11.0,>=10.0 from https://files.pythonhosted.org/packages/d1/60/0a6cb94e25b981e428c1cdcc2b0a406ac6e1dfc78d8a81c8a4ee7510e853/websockets-10.4-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading websockets-10.4-cp311-cp311-macosx_10_9_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->yahoo_fin) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/site-packages (from bs4->requests-html->yahoo_fin) (4.12.3)
# Collecting lxml>=2.1 (from pyquery->requests-html->yahoo_fin)
#   Obtaining dependency information for lxml>=2.1 from https://files.pythonhosted.org/packages/f9/dc/9819d678570f5f348de134b54b93fcf52584d7afff875cd7122117932f53/lxml-5.1.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading lxml-5.1.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (3.5 kB)
# Collecting cssselect>=1.2.0 (from pyquery->requests-html->yahoo_fin)
#   Obtaining dependency information for cssselect>=1.2.0 from https://files.pythonhosted.org/packages/06/a9/2da08717a6862c48f1d61ef957a7bba171e7eefa6c0aa0ceb96a140c2a6b/cssselect-1.2.0-py2.py3-none-any.whl.metadata
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting zipp>=0.5 (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin)
#   Obtaining dependency information for zipp>=0.5 from https://files.pythonhosted.org/packages/d9/66/48866fc6b158c81cc2bfecc04c480f105c6040e8b077bc54c634b4a67926/zipp-3.17.0-py3-none-any.whl.metadata
#   Downloading zipp-3.17.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/site-packages (from pyee<12.0.0,>=11.0.0->pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.8.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/site-packages (from beautifulsoup4->bs4->requests-html->yahoo_fin) (2.5)
# Downloading yahoo_fin-0.8.9.1-py3-none-any.whl (10 kB)
# Downloading feedparser-6.0.11-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 3.1 MB/s eta 0:00:00
# Downloading pandas-2.2.1-cp311-cp311-macosx_10_9_x86_64.whl (12.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 31.4 MB/s eta 0:00:0000:0100:01
# Downloading requests_html-0.10.0-py3-none-any.whl (13 kB)
# Downloading numpy-1.26.4-cp311-cp311-macosx_10_9_x86_64.whl (20.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 29.7 MB/s eta 0:00:0000:0100:01
# Downloading pyppeteer-2.0.0-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.9/82.9 kB 2.9 MB/s eta 0:00:00
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 6.3 MB/s eta 0:00:00:00:01
# Downloading urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 4.9 MB/s eta 0:00:00
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Downloading fake_useragent-1.4.0-py3-none-any.whl (15 kB)
# Downloading parse-1.20.1-py2.py3-none-any.whl (20 kB)
# Downloading pyquery-2.0.0-py3-none-any.whl (22 kB)
# Downloading w3lib-2.1.2-py3-none-any.whl (21 kB)
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Downloading importlib_metadata-7.0.1-py3-none-any.whl (23 kB)
# Downloading lxml-5.1.0-cp311-cp311-macosx_10_9_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 25.2 MB/s eta 0:00:0000:0100:01
# Downloading pyee-11.1.0-py3-none-any.whl (15 kB)
# Downloading tqdm-4.66.2-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 2.6 MB/s eta 0:00:00
# Downloading websockets-10.4-cp311-cp311-macosx_10_9_x86_64.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 4.0 MB/s eta 0:00:00
# Downloading zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6047 sha256=e0328967245723b9275cb7bb032dd67e66734a04d69d0eba8e839204b1b0f8f3
#   Stored in directory: /Users/jim/Library/Caches/pip/wheels/3b/25/2a/105d6a15df6914f4d15047691c6c28f9052cc1173e40285d03
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, parse, fake-useragent, appdirs, zipp, websockets, w3lib, urllib3, tzdata, tqdm, pyee, numpy, lxml, feedparser, cssselect, pyquery, pandas, importlib-metadata, bs4, pyppeteer, requests-html, yahoo_fin
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.2
#     Uninstalling urllib3-2.0.2:
#       Successfully uninstalled urllib3-2.0.2
# Successfully installed appdirs-1.4.4 bs4-0.0.2 cssselect-1.2.0 fake-useragent-1.4.0 feedparser-6.0.11 importlib-metadata-7.0.1 lxml-5.1.0 numpy-1.26.4 pandas-2.2.1 parse-1.20.1 pyee-11.1.0 pyppeteer-2.0.0 pyquery-2.0.0 requests-html-0.10.0 sgmllib3k-1.0.0 tqdm-4.66.2 tzdata-2024.1 urllib3-1.26.18 w3lib-2.1.2 websockets-10.4 yahoo_fin-0.8.9.1 zipp-3.17.0
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: /usr/local/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip

# %%
from yahoo_fin import options as op

#input ticker
ticker = 'SPY'

# get expiration dates
expirationDates = op.get_expiration_dates(ticker)

print("\nAll expiration dates for SPY:\n\n", expirationDates)

# call and put option data
callData = op.get_calls(ticker, date = expirationDates[0])
putData = op.get_puts(ticker, date = expirationDates[0])

# chain data (doesn't seem to work?) 
# chainData = op.get_option_chain(ticker, date = expirationDates[0])

print("\nCall contracts for closest expiration:\n\n", callData)
# Out:
# All expiration dates for SPY:
#
#  ['March 6, 2024', 'March 7, 2024', 'March 8, 2024', 'March 11, 2024', 'March 12, 2024', 'March 13, 2024', 'March 14, 2024', 'March 15, 2024', 'March 18, 2024', 'March 22, 2024', 'March 28, 2024', 'April 5, 2024', 'April 12, 2024', 'April 19, 2024', 'April 30, 2024', 'May 17, 2024', 'May 31, 2024', 'June 21, 2024', 'June 28, 2024', 'July 19, 2024', 'July 31, 2024', 'August 16, 2024', 'August 30, 2024', 'September 20, 2024', 'September 30, 2024', 'December 20, 2024', 'December 31, 2024', 'January 17, 2025', 'March 21, 2025', 'June 20, 2025', 'December 19, 2025', 'January 16, 2026', 'December 18, 2026']
# /usr/local/lib/python3.11/site-packages/yahoo_fin/options.py:42: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(requests.get(site, headers=headers).text)
# Call contracts for closest expiration:
#
#           Contract Name         Last Trade Date  Strike  Last Price    Bid  \
# 0   SPY240306C00425000   2024-03-04 1:39PM EST   425.0       84.66  82.46
# 1   SPY240306C00430000  2024-02-27 12:22PM EST   430.0       79.66  77.46
# 2   SPY240306C00434000   2024-02-26 3:27PM EST   434.0       73.58  73.45
# 3   SPY240306C00436000   2024-03-05 2:36PM EST   436.0       70.56  71.45
# 4   SPY240306C00438000   2024-03-04 9:55AM EST   438.0       74.69  69.45
# ..                 ...                     ...     ...         ...    ...
# 81  SPY240306C00535000  2024-03-05 10:53AM EST   535.0        0.01   0.00
# 82  SPY240306C00540000   2024-03-04 9:49AM EST   540.0        0.01   0.00
# 83  SPY240306C00545000  2024-03-04 10:43AM EST   545.0        0.01   0.00
# 84  SPY240306C00550000   2024-03-04 2:41PM EST   550.0        0.01   0.00
# 85  SPY240306C00555000   2024-02-27 9:30AM EST   555.0        0.01   0.00
#
#       Ask  Change % Change Volume  Open Interest Implied Volatility
# 0   82.93   -3.14   -3.58%      1              7            180.08%
# 1   77.93    3.47   +4.55%      1             75            170.02%
# 2   73.92    0.00        -      4              2            161.33%
# 3   71.92   -0.96   -1.34%      2              1            157.42%
# 4   69.92    0.00        -      3              0            153.42%
# ..    ...     ...      ...    ...            ...                ...
# 81   0.01    0.00        -      1           1084             37.50%
# 82   0.01    0.00        -      1           1143             42.97%
# 83   0.01    0.00        -      1            239             49.22%
# 84   0.00    0.00        -      6           1642             25.00%
# 85   0.01    0.00        -      -              1             56.25%
#
# [86 rows x 11 columns]
# /usr/local/lib/python3.11/site-packages/yahoo_fin/options.py:42: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(requests.get(site, headers=headers).text)
